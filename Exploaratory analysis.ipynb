# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\olympic_games.csv")

# %%
df
# Out:
#       year games_type host_country host_city  athletes  teams  competitions  \
# 0     2022     Winter        China   Beijing      2834     91           109
# 1     2022     Winter        China   Beijing      2834     91           109
# 2     2022     Winter        China   Beijing      2834     91           109
# 3     2022     Winter        China   Beijing      2834     91           109
# 4     2022     Winter        China   Beijing      2834     91           109
# ...    ...        ...          ...       ...       ...    ...           ...
# 1776  1896     Summer       Greece    Athens       241     14            43
# 1777  1896     Summer       Greece    Athens       241     14            43
# 1778  1896     Summer       Greece    Athens       241     14            43
# 1779  1896     Summer       Greece    Athens       241     14            43
# 1780  1896     Summer       Greece    Athens       241     14            43
#
#                        country  gold  silver  bronze
# ...

# %%
total =[]
for i in range(len(df)):
    total_value = df['gold'][i]+df['silver'][i]+df['bronze'][i]
    total.append(total_value)
df['total_medal']= total

# %%
df.head()
# Out:
#    year games_type host_country host_city  athletes  teams  competitions  \
# 0  2022     Winter        China   Beijing      2834     91           109
# 1  2022     Winter        China   Beijing      2834     91           109
# 2  2022     Winter        China   Beijing      2834     91           109
# 3  2022     Winter        China   Beijing      2834     91           109
# 4  2022     Winter        China   Beijing      2834     91           109
#
#      country  gold  silver  bronze  total_medal
# 0  Australia     1       2       1            4
# 1    Austria     7       7       4           18
# 2    Belarus     0       2       0            2
# 3    Belgium     1       0       1            2
# 4     Canada     4       8      14           26

# %%
df.tail()
# Out:
#       year games_type host_country host_city  athletes  teams  competitions  \
# 1776  1896     Summer       Greece    Athens       241     14            43
# 1777  1896     Summer       Greece    Athens       241     14            43
# 1778  1896     Summer       Greece    Athens       241     14            43
# 1779  1896     Summer       Greece    Athens       241     14            43
# 1780  1896     Summer       Greece    Athens       241     14            43
#
#                        country  gold  silver  bronze  total_medal
# 1776                   Hungary     2       1       3            6
# 1777                Mixed team     1       0       1            2
# 1778               Switzerland     1       2       0            3
# 1779            United Kingdom     3       3       3            9
# 1780  United States of America    11       7       2           20

# %%
df.describe()
# Out:
#               year      athletes        teams  competitions         gold  \
# count  1781.000000   1781.000000  1781.000000   1781.000000  1781.000000
# mean   1980.679394   6135.094329   118.057833    185.499719     3.747333
# std      31.902572   3899.002862    68.583661    100.780207     7.557803
# min    1896.000000    241.000000    12.000000     14.000000     0.000000
# 25%    1960.000000   2566.000000    59.000000    102.000000     0.000000
# 50%    1988.000000   5338.000000    92.000000    172.000000     1.000000
# 75%    2008.000000  10568.000000   199.000000    300.000000     4.000000
# max    2022.000000  11420.000000   207.000000    339.000000    83.000000
#
#             silver       bronze  total_medal
# count  1781.000000  1781.000000  1781.000000
# mean      3.723189     3.976418    11.446940
# std       6.388830     6.146937    19.381044
# min       0.000000     0.000000     1.000000
# 25%       0.000000     1.000000     2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          1781 non-null   int64
#  1   games_type    1781 non-null   object
#  2   host_country  1781 non-null   object
#  3   host_city     1781 non-null   object
#  4   athletes      1781 non-null   int64
#  5   teams         1781 non-null   int64
#  6   competitions  1781 non-null   int64
#  7   country       1781 non-null   object
#  8   gold          1781 non-null   int64
#  9   silver        1781 non-null   int64
#  10  bronze        1781 non-null   int64
#  11  total_medal   1781 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 167.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
pd.isna(df).sum()
# Out:
# year            0
# games_type      0
# host_country    0
# host_city       0
# athletes        0
# teams           0
# competitions    0
# country         0
# gold            0
# silver          0
# bronze          0
# total_medal     0
# dtype: int64

# %%
df.shape
# Out:
# (1781, 12)

# %% [markdown]
# # Analyse the maximum count of gold  acheived

# %%
gold_max= df.groupby('gold').max()[['country','year','games_type']].reset_index(level=[0])

# %%
gold_max
# Out:
#     gold                               country  year games_type
# 0      0                                Zambia  2022     Winter
# 1      1                              Zimbabwe  2022     Winter
# 2      2                            Yugoslavia  2022     Winter
# 3      3                            Yugoslavia  2022     Winter
# 4      4                            Uzbekistan  2022     Winter
# 5      5              United States of America  2022     Winter
# 6      6              United States of America  2022     Winter
# 7      7                            Yugoslavia  2022     Winter
# 8      8              United States of America  2022     Winter
# 9      9              United States of America  2022     Winter
# 10    10              United States of America  2020     Winter
# 11    11              United States of America  2018     Winter
# 12    12                                Sweden  2022     Winter
# 13    13                                  USSR  2012     Winter
# ...

# %%
fig = plt.figure(figsize = [28,10])
sns.barplot(x= 'year',y = 'gold',data = gold_max,hue ='country',width = 2)
# Out:
# <Axes: xlabel='year', ylabel='gold'>

# %% [markdown]
# **the greatest value of gold  acheived is 83 in the year of 1984 by USA in summer_games category**

# %% [markdown]
# ## Analysing the minimum value of gold acheived

# %%
gold_min = df.groupby('gold').min()[['country','year','games_type']].reset_index(level =[0])
gold_min
# Out:
#     gold                               country  year games_type
# 0      0                           Afghanistan  1904     Summer
# 1      1                               Algeria  1896     Summer
# 2      2                               Algeria  1896     Summer
# 3      3                             Argentina  1896     Summer
# 4      4                             Australia  1900     Summer
# 5      5                             Australia  1896     Summer
# 6      6                             Australia  1900     Summer
# 7      7                             Australia  1896     Summer
# 8      8                             Australia  1900     Summer
# 9      9                             Australia  1912     Summer
# 10    10                              Bulgaria  1896     Summer
# 11    11                                Canada  1896     Summer
# 12    12                               Germany  1932     Summer
# 13    13                             Australia  1920     Summer
# ...

# %%
figure = plt.figure(figsize = (40,10))
sns.barplot(x='year',y = 'gold',data = gold_min,hue = 'country',width = 1)
# Out:
# <Axes: xlabel='year', ylabel='gold'>

# %% [markdown]
# **fig shows many countries like Argentina acheived  1 nos of gold**

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ## Analyse the highest value of silver acheived

# %%
silver_max = df.groupby('silver').max()[['country','year','games_type']].reset_index(level=[0])

# %%
silver_max
# Out:
#     silver                     country  year games_type
# 0        0                    Zimbabwe  2022     Winter
# 1        1                    Zimbabwe  2022     Winter
# 2        2                  Yugoslavia  2022     Winter
# 3        3                    Zimbabwe  2022     Winter
# 4        4                  Yugoslavia  2022     Winter
# 5        5    United States of America  2022     Winter
# 6        6    United States of America  2022     Winter
# 7        7    United States of America  2022     Winter
# 8        8    United States of America  2022     Winter
# 9        9    United States of America  2016     Winter
# 10      10    United States of America  2022     Winter
# 11      11              United Kingdom  2020     Winter
# 12      12    United States of America  2022     Winter
# 13      13    United States of America  2010     Winter
# 14      14    United States of America  2020     Winter
# 15      15    United States of America  2012     Winter
# ...

# %%
fig = plt.figure(figsize =[20,5])
sns.barplot(x= 'year',y = 'silver',data=silver_max,hue ='country',width =1)
# Out:
# <Axes: xlabel='year', ylabel='silver'>

# %% [markdown]
# **Highest value of silver is acheived by USA in year of 1904 in summer_game category**

# %% [markdown]
# ## Analyse the lowest value of silver

# %%
df['silver'].min()
# Out:
# 0

# %%
silver_min = df.groupby('silver').min()[['country','year','games_type']].reset_index(level=[0])

# %%
silver_min
# Out:
#     silver                               country  year games_type
# 0        0                           Afghanistan  1896     Summer
# 1        1                               Algeria  1896     Summer
# 2        2                               Algeria  1896     Summer
# 3        3                             Argentina  1896     Summer
# 4        4                               Austria  1896     Summer
# 5        5                               Austria  1896     Summer
# 6        6                             Australia  1908     Summer
# 7        7                             Australia  1896     Summer
# 8        8                             Australia  1900     Summer
# 9        9                             Australia  1920     Summer
# 10      10                              Bulgaria  1920     Summer
# 11      11                             Australia  1928     Summer
# 12      12                               Belgium  1908     Summer
# ...

# %%
figure = plt.figure(figsize = [35,12])
sns.barplot(x='year',y='silver',data=silver_min,hue ='country',width =1)
# Out:
# <Axes: xlabel='year', ylabel='silver'>

# %% [markdown]
# **fig represents countries like Argentina acheived minimum of 1 silver medal**

# %% [markdown]
# ## Analyse the highest value of bronze acheived

# %%
bronze_max = df.groupby('bronze').max()[['country','year','games_type']].reset_index(level=[0])
bronze_max
# Out:
#     bronze                               country  year games_type
# 0        0                              Zimbabwe  2022     Winter
# 1        1                              Zimbabwe  2022     Winter
# 2        2                            Yugoslavia  2022     Winter
# 3        3                            Yugoslavia  2020     Winter
# 4        4                            Yugoslavia  2022     Winter
# 5        5                            Yugoslavia  2022     Winter
# 6        6              United States of America  2022     Winter
# 7        7                            Yugoslavia  2022     Winter
# 8        8                        United Kingdom  2022     Winter
# 9        9                        United Kingdom  2022     Winter
# 10      10              United States of America  2020     Winter
# 11      11              United States of America  2020     Winter
# 12      12              United States of America  2020     Summer
# ...

# %%
fig = plt.figure(figsize =[20,7])
sns.barplot(x = 'year',y ='bronze',data = bronze_max,hue ='country',width =1.3)
# Out:
# <Axes: xlabel='year', ylabel='bronze'>

# %% [markdown]
# **fig shows the highest value acheived is 77 by USA in the year of 1904 in summer games**

# %% [markdown]
# ## Analyse the lowest value of bronze acheived

# %%
bronze_min = df.groupby('bronze').min()[['country','year','games_type']].reset_index(level =[0])

# %%
bronze_min
# Out:
#     bronze                               country  year games_type
# 0        0                               Algeria  1896     Summer
# 1        1                           Afghanistan  1896     Summer
# 2        2                               Algeria  1896     Summer
# 3        3                               Algeria  1896     Summer
# 4        4                             Argentina  1900     Summer
# 5        5                             Australia  1908     Summer
# 6        6                             Australia  1900     Summer
# 7        7                               Austria  1912     Summer
# 8        8                               Austria  1952     Summer
# 9        9                               Austria  1900     Summer
# 10      10                             Australia  1908     Summer
# 11      11                             Australia  1908     Summer
# 12      12                             Australia  1908     Summer
# ...

# %%
bronze_min['bronze'].count()
# Out:
# 42

# %%
fig = plt.figure(figsize=[35,10])
sns.barplot(x='year',y ='bronze',data = bronze_min,hue ='country',width =0.8)
# Out:
# <Axes: xlabel='year', ylabel='bronze'>

# %% [markdown]
# **fig shows minimum of 1 medal acheived by  Afganistan,Algeria and Argentina**

# %% [markdown]
# ## Analyse Which country  acheived  maximum number of medals

# %%
df.describe()
# Out:
#               year      athletes        teams  competitions         gold  \
# count  1781.000000   1781.000000  1781.000000   1781.000000  1781.000000
# mean   1980.679394   6135.094329   118.057833    185.499719     3.747333
# std      31.902572   3899.002862    68.583661    100.780207     7.557803
# min    1896.000000    241.000000    12.000000     14.000000     0.000000
# 25%    1960.000000   2566.000000    59.000000    102.000000     0.000000
# 50%    1988.000000   5338.000000    92.000000    172.000000     1.000000
# 75%    2008.000000  10568.000000   199.000000    300.000000     4.000000
# max    2022.000000  11420.000000   207.000000    339.000000    83.000000
#
#             silver       bronze  total_medal
# count  1781.000000  1781.000000  1781.000000
# mean      3.723189     3.976418    11.446940
# std       6.388830     6.146937    19.381044
# min       0.000000     0.000000     1.000000
# 25%       0.000000     1.000000     2.000000
# ...

# %%
df2 = df.groupby('total_medal').max()[['country','year']].reset_index(level =[0])

# %%
df2
# Out:
#     total_medal                   country  year
# 0             1                  Zimbabwe  2022
# 1             2                Yugoslavia  2022
# 2             3                  Zimbabwe  2022
# 3             4                  Zimbabwe  2022
# 4             5                Yugoslavia  2020
# ..          ...                       ...   ...
# 91          132                      USSR  1988
# 92          146            United Kingdom  1908
# 93          174  United States of America  1984
# 94          195                      USSR  1980
# 95          231  United States of America  1904
#
# [96 rows x 3 columns]

# %%
fig = plt.figure(figsize = [20,15])
sns.barplot(x = 'year',y ='total_medal',hue='country',data = df2,width =0.8)
# Out:
# <Axes: xlabel='year', ylabel='total_medal'>

# %% [markdown]
# **The fig shows that in the year between 1900 and 1904 the highest amount of medals acheived and it was by USA and the count is 231**

# %% [markdown]
# ## Analyse the lowest total count of medals acheived

# %%
low_count = df.groupby('total_medal').min()[['country','year']].reset_index(level =[0])

# %%
low_count
# Out:
#     total_medal                   country  year
# 0             1               Afghanistan  1904
# 1             2                   Algeria  1896
# 2             3                   Algeria  1896
# 3             4                 Argentina  1904
# 4             5                   Algeria  1896
# ..          ...                       ...   ...
# 91          132                      USSR  1988
# 92          146            United Kingdom  1908
# 93          174  United States of America  1984
# 94          195                      USSR  1980
# 95          231  United States of America  1904
#
# [96 rows x 3 columns]

# %%
fig1 = plt.figure(figsize = [30,15])
sns.barplot(x = 'year',y ='total_medal',hue ='country',data =low_count,width = 0.8)
# Out:
# <Axes: xlabel='year', ylabel='total_medal'>

# %% [markdown]
# **the minimum count of total medals acheived was 1 in the whole years by many countries.**

# %% [markdown]
# ## Analyse which country acheived more medals in total and in what game

# %%
games_medals = df.groupby('total_medal').max()[['games_type','country']].reset_index(level=[0])

# %%
games_medals
# Out:
#     total_medal games_type                   country
# 0             1     Winter                  Zimbabwe
# 1             2     Winter                Yugoslavia
# 2             3     Winter                  Zimbabwe
# 3             4     Winter                  Zimbabwe
# 4             5     Winter                Yugoslavia
# ..          ...        ...                       ...
# 91          132     Summer                      USSR
# 92          146     Summer            United Kingdom
# 93          174     Summer  United States of America
# 94          195     Summer                      USSR
# 95          231     Summer  United States of America
#
# [96 rows x 3 columns]

# %%
fig0 = plt.figure(figsize = [40,10])
sns.barplot(x = 'country',y ='total_medal',hue ='games_type',data =games_medals)
# Out:
# <Axes: xlabel='country', ylabel='total_medal'>

# %% [markdown]
# **USSR acheived more medals in summer game type**

# %% [markdown]
# ## Analyse which country hoisted olympics  more

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          1781 non-null   int64
#  1   games_type    1781 non-null   object
#  2   host_country  1781 non-null   object
#  3   host_city     1781 non-null   object
#  4   athletes      1781 non-null   int64
#  5   teams         1781 non-null   int64
#  6   competitions  1781 non-null   int64
#  7   country       1781 non-null   object
#  8   gold          1781 non-null   int64
#  9   silver        1781 non-null   int64
#  10  bronze        1781 non-null   int64
#  11  total_medal   1781 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 167.1+ KB

# %%
country=df.groupby('host_country')['year'].nunique().reset_index ( level =[0])
country
# Out:
#                    host_country  year
# 0                     Australia     1
# 1             Australia, Sweden     1
# 2                       Austria     2
# 3                       Belgium     1
# 4                        Brazil     1
# 5                        Canada     3
# 6                         China     2
# 7   Federal Republic of Germany     1
# 8                       Finland     1
# 9                        France     4
# 10                      Germany     1
# 11                Great Britain     3
# 12                       Greece     2
# 13                        Italy     3
# 14                        Japan     4
# 15                       Mexico     1
# 16                  Netherlands     1
# 17                       Norway     2
# 18            Republic of Korea     2
# 19           Russian Federation     1
# 20                        Spain     1
# 21                       Sweden     1
# 22                  Switzerland     2
# 23                         USSR     1
# ...

# %%
fig = plt.figure(figsize = [35,10])
sns.barplot(x ='host_country',y = 'year',data = country)
# Out:
# <Axes: xlabel='host_country', ylabel='year'>

# %% [markdown]
# **From the above graph we can analyse that United States had hoisted olympic more times(7)**

# %% [markdown]
# ## Analyse the year and game type in which more number of athletes participate

# %%
df.describe()
# Out:
#               year      athletes        teams  competitions         gold  \
# count  1781.000000   1781.000000  1781.000000   1781.000000  1781.000000
# mean   1980.679394   6135.094329   118.057833    185.499719     3.747333
# std      31.902572   3899.002862    68.583661    100.780207     7.557803
# min    1896.000000    241.000000    12.000000     14.000000     0.000000
# 25%    1960.000000   2566.000000    59.000000    102.000000     0.000000
# 50%    1988.000000   5338.000000    92.000000    172.000000     1.000000
# 75%    2008.000000  10568.000000   199.000000    300.000000     4.000000
# max    2022.000000  11420.000000   207.000000    339.000000    83.000000
#
#             silver       bronze  total_medal
# count  1781.000000  1781.000000  1781.000000
# mean      3.723189     3.976418    11.446940
# std       6.388830     6.146937    19.381044
# min       0.000000     0.000000     1.000000
# 25%       0.000000     1.000000     2.000000
# ...

# %%
val = VAL.groupby('athletes').max()[['year','games_type']].reset_index(level =[0])

# %%
val
# Out:
#     athletes  year games_type
# 0        241  1896     Summer
# 1        252  1932     Winter
# 2        260  1924     Winter
# 3        464  1928     Winter
# 4        646  1936     Winter
# 5        651  1904     Summer
# 6        665  1960     Winter
# 7        669  1948     Winter
# 8        694  1952     Winter
# 9        821  1956     Winter
# 10      1006  1972     Winter
# 11      1072  1980     Winter
# 12      1091  1964     Winter
# 13      1123  1976     Winter
# 14      1158  1968     Winter
# 15      1226  1900     Summer
# 16      1272  1984     Winter
# 17      1334  1932     Summer
# 18      1423  1988     Winter
# 19      1737  1994     Winter
# 20      1801  1992     Winter
# 21      2008  1908     Summer
# 22      2176  1998     Winter
# 23      2399  2002     Winter
# 24      2407  1912     Summer
# 25      2508  2006     Winter
# 26      2566  2010     Winter
# 27      2622  1920     Summer
# 28      2780  2014     Winter
# 29      2833  2018     Winter
# ...

# %%
fig = plt.figure(figsize =[30,10])
sns.barplot(x='year',y ='athletes',hue ='games_type',data = val)
# Out:
# <Axes: xlabel='year', ylabel='athletes'>

# %% [markdown]
# **The above fig shows more number of athletes ie,above 11k has participated in summer games type on 2020**

# %% [markdown]
# ### conclusion

# %% [markdown]
# **To be concluded that more number of gold,silver and bronze medals have gained by USA in 1984 and 1904 respectively and highest cumulative total of medals were acheived by USSR in summer types of games as more number of athletes participated in summer types and USA becomes the most hosted country of olympic games**
